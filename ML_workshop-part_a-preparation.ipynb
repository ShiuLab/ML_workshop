# %% [markdown]
# ---
# # __Machine Learning Part-A: Pre-Workshop Preparation__

# %% [markdown]
# ## Learning objectives
#
# At the end of the exercise, you should be able to:
# - Distinguish unsupervised and supervised learning.
# - Distinguish regression and classification tasks.
# - Explain the major steps in a machine learning project.
# - Check that the ncessary software packages are installed.

# %% [markdown]
# ----
# <a name="Introduction_to_Machine_Learning"></a>
# # 1. Introduction to Machine Learning

# %% [markdown]
# &#9989; **<font color=blue>DO THIS:</font>** Please watch the following two videos introduces many key concepts in machine learning.
#
# To run the code cell, press `SHIFT`+`ENTER`.

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("cfj6yaYE86U",width=640,height=360)

# %% [markdown]
# &#9989; **<font color=red>QUESTION:</font>**  Answer the following:
# 1. What does train a model mean?
# 1. What are the differences between attribute, feature, and observation?
# 1. What is the difference between Supervised and Unsupervised machine learning?

# %% [markdown]
# <font size=+3>&#9998;</font> Double click this cell and put your answer to the above questions below:
#
# 1. Your answer
# 2. Your answer
# 3. Your answer

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("-_XYmr4vkwc",width=640,height=360)

# %% [markdown]
# &#9989; **<font color=red>QUESTION:</font>** What is the difference between Regression and Classification models?

# %% [markdown]
# <font size=+3>&#9998;</font> Put your answer to the above question here

# %% [markdown]
# ----
# <a name="workflow"></a>
#
# # 2. Machine learning workflow
#
# Below are the major steps in a machine learning project. Please go through them and bring questions.
#
# |Step|Purpose|Notes|
# |---|---|---|
# |1|State the question and frame it as a machine learning problem|Is it a supervised or unsupervised learning problem? There are other major types (semi-supervised and reinforced learning).|
# |2|Collect data, and exploratory data analysis (EDA)|Apply four types of EDA.|
# |3|Split training and testing data|Seperate out testing data for evaluation purpose.|
# |4|Engineer features| - Format data, impute missing values, normalize/scale features.<br>- Transform feature values, select informative features,<br>- Create combinatorial features (e.g., the interaction terms for basic linear model).<br>- Do dimension reduction to reduce the number of features.|
# |5|Select models| - There are many models/algorithms/classifers making different assumptions about how modeling should be done. Thus, it is important to go through a wide range of them.<br>- And for each model/algorith, we need to tune __hyperparameters__, i.e., parameters that are set manually.<br>- Cross-validate model, i.e., separate data into training/validation subsets, use the training subset to train a model and score the model with the validation subset. Then split the training/validation subset again but differently, train and score. Repeat the process $k$ times.|
# |6|Repeat 2-5|Work to iteratively improve the models.|
# |7|Evaluate the best performing model|- After a best performing model is identified based on the training data, the model is applied to the testing set.<br>- Various model performance metric can be used to access how good the model is.|
# |8|Interpret the model|- Dissect the model to better understand how it works.<br>- Identify most informative features for the best performing model.<br>- Assess the reasons behind false predictions to further improve model.|
# |9|Deploy model|Apply model to new data and make predictions.|

# %% [markdown]
# ----
# <a name="example"></a>
# # 3. Setting up for the workshop

# %% [markdown]
# ## 3.1 Setting up required packages
#
# &#9989; **<font color=blue>DO THIS:</font>** In Jupyter, you can execute terminal command by adding `!` in front of the commandline. Let's use this message to install the required packages:
#
# - Create a new conda environment called `sklearn`.
# - Activate the environment,
# - Install `sklearn`, `pandas`, `matplotlib`, `seaborn`, `imblearn`, `numpy`, `shap`, `ipywidgets`, `tqdm`.

# %%
# Test your install
import sklearn, pandas, matplotlib, seaborn, imblearn, numpy, shap, tqdm

# %% [markdown]
# __Note__: If you encounter `ModuleNotFoundError`:
# - Close the terminal window.
# - Close your browser with the Jupyter Lab instance.
# - Open the terminal window, and follow the instruction before about opening this notebook.
# - Re-run the above code cell.
#
# If that still won't work, don't fret, we will see if we can fix this before workshop.

# %% [markdown]
# ## 3.2 Where the data is from
#
# We will be using a dataset `enzyme_gene.csv` from a [PNAS paper](https://pubmed.ncbi.nlm.nih.gov/30674669/). Let's use this dataset to illustrate how an end-to-end machine learning project is done.

# %% [markdown]
# &#9989; **<font color=red>QUESTION:</font>**  Read the abstract for the paper. In the space below, state the biological problem as a machine learning problem.

# %% [markdown]
# <font size=+3>&#9998;</font> Put your answer to the above question here

# %% [markdown]
# ---------
# ### Congratulations, we're done for now. Will see you in the workshop!
